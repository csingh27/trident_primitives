# %%
import os
import sys
import json
import numpy as np
import pandas as pd
import matplotlib.pylab as plt

# %%
base_dir = os.path.abspath(os.path.join(os.getcwd(), '..'))

# %%
base_dir
# Out:
# '/home/dfki.uni-bremen.de/jguo/Documents/PhysWM/trident_primitives'

# %%
# change here
experiment_name = 'MAML_primitives_5-way_5-shot_1-queries_iter_150_batch_3'

with open(os.path.join(base_dir,'MAML_results',experiment_name,'results.json')) as f:
    results = json.load(f)


mean_train_err = sum(results['train_err'].values())/len(results['train_err'])
mean_valid_err = sum(results['valid_err'].values())/len(results['valid_err'])

mean_train_acc = sum(results['train_acc'].values())/len(results['train_acc'])
mean_valid_acc = sum(results['valid_acc'].values())/len(results['valid_acc'])

print('mean train error:', mean_train_err)
print('mean valid error:', mean_valid_err)
print('test error:', results['test_err'])

print('mean train acc:', mean_train_acc )
print('mean valid acc:', mean_valid_acc )
print('test acc:', results['test_acc'])
# Out:
# mean train error: 0.28433034039205984
# mean valid error: 0.2818380141589378
# test error: 0.27526899178822833
# mean train acc: 0.23925926393932775
# mean valid acc: 0.24518519004185998
# test acc: 0.2777777810891469

# %%
list_train_acc = results['train_acc'].items()
list_val_acc = results['valid_acc'].items()

_, train_acc = zip(*list_train_acc) # unpack a list of pairs into two tuples
_, val_acc = zip(*list_val_acc) # unpack a list of pairs into two tuples

x = range(len(results['train_acc']))
plt.plot(x, train_err,'-b')
plt.plot(x, val_err,'-r')

plt.show()

# %%
list_train_err = results['train_err'].items()
list_val_err = results['valid_err'].items()

_, train_err = zip(*list_train_err) # unpack a list of pairs into two tuples
_, val_err = zip(*list_val_err) # unpack a list of pairs into two tuples

x = range(len(results['train_err']))
plt.plot(x, train_err,'-b')
plt.plot(x, val_err,'-r')

plt.show()

# %%
experiment_name = 'MAML_primitives_5-way_5-shot_1-queries_iter_150' ## change here

with open(os.path.join(base_dir,'MAML_results',experiment_name,'results.json')) as f:
    results = json.load(f)

mean_train_err = sum(results['train_err'].values())/len(results['train_err'])
mean_valid_err = sum(results['valid_err'].values())/len(results['valid_err'])

mean_train_acc = sum(results['train_acc'].values())/len(results['train_acc'])
mean_valid_acc = sum(results['valid_acc'].values())/len(results['valid_acc'])

print('mean train error:', mean_train_err)
print('mean valid error:', mean_valid_err)
print('test error:', results['test_err'])

print('mean train acc:', mean_train_acc )
print('mean valid acc:', mean_valid_acc )
print('test acc:', results['test_acc'])
# Out:
# mean train error: 0.3142902432878812
# mean valid error: 0.30335004528363546
# test error: 0.2539994716644287
# mean train acc: 0.20888889302810032
# mean valid acc: 0.23777778228123983
# test acc: 0.3333333432674408

# %%
list_train_acc = results['train_acc'].items()
list_val_acc = results['valid_acc'].items()

_, train_acc = zip(*list_train_acc) # unpack a list of pairs into two tuples
_, val_acc = zip(*list_val_acc) # unpack a list of pairs into two tuples

x = range(len(results['train_acc']))
plt.plot(x, train_err,'-b')
plt.plot(x, val_err,'-r')

plt.show()

# %%
list_train_err = results['train_err'].items()
list_val_err = results['valid_err'].items()

_, train_err = zip(*list_train_err) # unpack a list of pairs into two tuples
_, val_err = zip(*list_val_err) # unpack a list of pairs into two tuples

x = range(len(results['train_err']))
plt.plot(x, train_err,'-b')
plt.plot(x, val_err,'-r')

plt.show()

# %%
experiment_name = 'MAML_primitives_5-way_5-shot_1-queries_iter_300' ## change here

with open(os.path.join(base_dir,'MAML_results',experiment_name,'results.json')) as f:
    results = json.load(f)

mean_train_err = sum(results['train_err'].values())/len(results['train_err'])
mean_valid_err = sum(results['valid_err'].values())/len(results['valid_err'])

mean_train_acc = sum(results['train_acc'].values())/len(results['train_acc'])
mean_valid_acc = sum(results['valid_acc'].values())/len(results['valid_acc'])

print('mean train error:', mean_train_err)
print('mean valid error:', mean_valid_err)
print('test error:', results['test_err'])

print('mean train acc:', mean_train_acc )
print('mean valid acc:', mean_valid_acc )
print('test acc:', results['test_acc'])
# Out:
# mean train error: 0.2956383326649666
# mean valid error: 0.286041251172622
# test error: 0.245200052857399
# mean train acc: 0.21388889347513518
# mean valid acc: 0.2505555604398251
# test acc: 0.1666666716337204

# %%
list_train_acc = results['train_acc'].items()
list_val_acc = results['valid_acc'].items()

_, train_acc = zip(*list_train_acc) # unpack a list of pairs into two tuples
_, val_acc = zip(*list_val_acc) # unpack a list of pairs into two tuples

x = range(len(results['train_acc']))
plt.plot(x, train_acc,'-b')
plt.plot(x, val_acc,'-r')

plt.show()

# %%
list_train_err = results['train_err'].items()
list_val_err = results['valid_err'].items()

_, train_err = zip(*list_train_err) # unpack a list of pairs into two tuples
_, val_err = zip(*list_val_err) # unpack a list of pairs into two tuples

x = range(len(results['train_err']))
plt.plot(x, train_err,'-b')
plt.plot(x, val_err,'-r')

plt.show()

# %% [markdown]
# ### Part 2: Using dataset without validation

# %%
experiment_name = 'MAML_primitives_wo_val_5-way_1-shot_1-queries_iter_150_batch_5_wo_val'

with open(os.path.join(base_dir,'MAML_results',experiment_name,'results.json')) as f:
    results = json.load(f)

mean_train_err = sum(results['train_err'].values())/len(results['train_err'])
mean_train_acc = sum(results['train_acc'].values())/len(results['train_acc'])

print('mean train error:', mean_train_err)
print('test error:', results['test_err'])

print('mean train acc:', mean_train_acc )
print('test acc:', results['test_acc'])
# Out:
# mean train error: 1.1062658530871077
# test error: 0.913336205482483
# mean train acc: 0.1333333333333333
# test acc: 0.0

# %%
list_train_acc = results['train_acc'].items()


_, train_acc = zip(*list_train_acc) # unpack a list of pairs into two tuples

x = range(len(results['train_acc']))
plt.plot(x, train_acc,'-b')

plt.show()

# %%
list_train_err = results['train_err'].items()


_, train_err = zip(*list_train_err) # unpack a list of pairs into two tuples

x = range(len(results['train_err']))
plt.plot(x, train_err,'-b')

plt.show()

# %%
experiment_name = 'MAML_primitives_wo_val_5-way_1-shot_1-queries_iter_60_batch_20_wo_val'

with open(os.path.join(base_dir,'MAML_results',experiment_name,'results.json')) as f:
    results = json.load(f)

mean_train_err = sum(results['train_err'].values())/len(results['train_err'])
mean_train_acc = sum(results['train_acc'].values())/len(results['train_acc'])

print('mean train error:', mean_train_err)
print('test error:', results['test_err'])

print('mean train acc:', mean_train_acc )
print('test acc:', results['test_acc'])
# Out:
# mean train error: 1.202567409947514
# test error: 0.9165251523256301
# mean train acc: 0.08916666666666666
# test acc: 0.025

# %%
list_train_acc = results['train_acc'].items()


_, train_acc = zip(*list_train_acc) # unpack a list of pairs into two tuples

x = range(len(results['train_acc']))
plt.plot(x, train_acc,'-r')

plt.show()

# %%
list_train_err = results['train_err'].items()


_, train_err = zip(*list_train_err) # unpack a list of pairs into two tuples

x = range(len(results['train_err']))
plt.plot(x, train_err,'-b')

plt.show()

# %%
MAML_primitives_wo_val_5-way_1-shot_1-queries_iter_300_batch_20_wo_val

# %%
experiment_name = 'MAML_primitives_wo_val_5-way_1-shot_1-queries_iter_300_batch_20_wo_val'

with open(os.path.join(base_dir,'MAML_results/8020',experiment_name,'results.json')) as f:
    results = json.load(f)

mean_train_err = sum(results['train_err'].values())/len(results['train_err'])
mean_train_acc = sum(results['train_acc'].values())/len(results['train_acc'])

print('mean train error:', mean_train_err)
print('test error:', results['test_err'])

print('mean train acc:', mean_train_acc )
print('test acc:', results['test_acc'])
# Out:
# mean train error: 0.8882164023170869
# test error: 0.7682194411754608
# mean train acc: 0.19599999999999998
# test acc: 0.25

# %%
list_train_acc = results['train_acc'].items()


_, train_acc = zip(*list_train_acc) # unpack a list of pairs into two tuples

x = range(len(results['train_acc']))
plt.plot(x, train_acc,'-r')

plt.show()

# %%
list_train_err = results['train_err'].items()


_, train_err = zip(*list_train_err) # unpack a list of pairs into two tuples

x = range(len(results['train_err']))
plt.plot(x, train_err,'-b')

plt.show()

# %%
experiment_name = 'MAML_primitives_wo_val_5-way_1-shot_1-queries_iter_300_batch_20_wo_val'

with open(os.path.join(base_dir,'MAML_results/6040',experiment_name,'results.json')) as f:
    results = json.load(f)

mean_train_err = sum(results['train_err'].values())/len(results['train_err'])
mean_train_acc = sum(results['train_acc'].values())/len(results['train_acc'])

print('mean train error:', mean_train_err)
print('test error:', results['test_err'])

print('mean train acc:', mean_train_acc )
print('test acc:', results['test_acc'])
# Out:
# mean train error: 0.44843289565046635
# test error: 0.39395731389522554
# mean train acc: 0.17412499999999992
# test acc: 0.2625

# %%
list_train_acc = results['train_acc'].items()


_, train_acc = zip(*list_train_acc) # unpack a list of pairs into two tuples

x = range(len(results['train_acc']))
plt.plot(x, train_acc,'-r')

plt.show()

# %%
list_train_err = results['train_err'].items()


_, train_err = zip(*list_train_err) # unpack a list of pairs into two tuples

x = range(len(results['train_err']))
plt.plot(x, train_err,'-b')

plt.show()
